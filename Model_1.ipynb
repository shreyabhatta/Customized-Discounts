# %% [markdown]
# This is a simple model using linear regression

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import math

# %%
#first we will make a model for new customers

#importing data
data = pd.read_csv("data_new_customers.csv",encoding='latin-1')
data.head(10)  #first ten observations of the data set
# Out:
#    Unnamed: 0  GTO_per_unit_vol            segment    sub_segment  \
# 0          29        338.927445  Entertainment Led         Events
# 1          81        258.933333      Institutional  Institutional
# 2         204        349.750000          Drink Led            Bar
# 3         205        379.936709          Drink Led            Bar
# 4         206        261.340000          Drink Led            Bar
# 5        5382        254.280000          Drink Led            Bar
# 6        7689        294.166667          Drink Led            Bar
# 7        7690        254.973050          Drink Led            Bar
# 8        9100        294.166667      Institutional  Institutional
# 9        9113        453.333333          Drink Led            Bar
#
#                                          Product_Set          Brand  \
# 0                        OW_CAN_JUPILER_JUPILER PILS        JUPILER
# 1                RETURNABLE_KEG_JUPILER_JUPILER PILS        JUPILER
# ...
